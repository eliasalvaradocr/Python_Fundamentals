# %%
import random as rd

# Primer Ejemplo
respuesta = rd.randint(1,100)
print(respuesta)

# Segundo Ejemplo
minimo = int(input("Valor minimo: "))
maximo = int(input("Valor maximo: "))

rango = rd.randint(minimo,maximo)
print(rango)

# %%
import turtle

turtle.pendown()
turtle.forward(100)
turtle.right(90)
turtle.forward(100)
turtle.right(90)
turtle.done()

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '__vsc_ipynb_file__', '_dh', '_i', '_i1', '_i2', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'open', 'quit', 'turtle']

# %%
def area_de_cuadrado(largo):
    area = largo * largo
    return area

test = area_de_cuadrado(30)
print(f'El area es {test}')
# Out:
# El area es 900

# %%
from math import pi as PI  

print(PI)
# Out:
# 3.141592653589793

# %%
import webbrowser

webbrowser.open("https://www.youtube.com/")
# Out:
# True

# %%
import datetime

start = datetime.date(2022,2,4) # Year, Month, Day
print(start)

pretty_start = start.strftime(" %A %d %B, %Y")
print(pretty_start)

# %%
import tkinter
 
print(tkinter.TkVersion)
print(tkinter.TclVersion)

tkinter._test() # Primera Ventana

mainWindow = tkinter.Tk()  
mainWindow.title("Hello World")  
mainWindow.geometry("640x480")

label = tkinter.Label(mainWindow, text = "Hello World")
label.grid(row=0, column=0)

leftFrame = tkinter.Frame(mainWindow)
leftFrame.grid(row=1,column=1)

canvas = tkinter.Canvas(leftFrame, relief = "raised", borderwidth=1)
canvas.grid(row=1, column=0)

rightFrame= tkinter.Frame(mainWindow)
rightFrame.grid(row=1,column=2, sticky="n")
button1 = tkinter.Button(rightFrame, text = "button1")
button2 = tkinter.Button(rightFrame, text = "button2")
button3 = tkinter.Button(rightFrame, text = "button3")
button1.grid(row=0, column=0)
button2.grid(row=1, column=0)
button3.grid(row=2, column=0)

# configuracion de columnas
mainWindow.columnconfigure(0, weight = 1)
mainWindow.columnconfigure(1, weight = 1)
mainWindow.grid_columnconfigure(2, weight = 1)

leftFrame.config(relief="sunken", borderwidth=1)
rightFrame.config(relief="sunken", borderwidth=1)
leftFrame.grid(sticky="ns")
rightFrame.grid(sticky="ns")



mainWindow.mainloop() # Segunda Ventana
# Out:
# 8.6
# 8.6

# %%
import random

for roll in range(10):
    print(random.randint(1,6), end="")
# Out:
# 2,3,3,1,1,2,4,2,2,6,
